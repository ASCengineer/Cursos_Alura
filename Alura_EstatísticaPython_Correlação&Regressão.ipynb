# %% [markdown]
# # Aula 1

# %% [markdown]
# ##Bibliotecas
#
# Verificar versões

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy
import statsmodels

# %%
print('Versão do pandas: %s', pd.__version__)
print('Versão do numpy: %s', np.__version__)
print('Versão do seaborn: %s', sns.__version__)
print('Versão do scipy: %s', scipy.__version__)
print('Versão do statsmodels: %s', statsmodels.__version__)
# Out:
# Versão do pandas: %s 1.3.5
# Versão do numpy: %s 1.21.6
# Versão do seaborn: %s 0.11.2
# Versão do scipy: %s 1.4.1
# Versão do statsmodels: %s 0.10.2

# %%
import statsmodels.api
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
''' Caso apresente problema, possível solução:'''
#!pip install scipy==1.2 --upgrade

"""após isso, reiniciar ambiente de execução"""
# Out:
# 'após isso, reiniciar ambiente de execução'

# %%
df = pd.read_csv('dados.csv')
df
# Out:
#        UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0      11     0     23    8              12    800  1.603808
# 1      11     1     23    2              12   1150  1.739790
# 2      11     1     35    8              15    880  1.760444
# 3      11     0     46    2               6   3500  1.783158
# 4      11     1     47    8               9    150  1.690631
# ...    ..   ...    ...  ...             ...    ...       ...
# 76835  53     1     46    2              11    812  1.687030
# 76836  53     0     30    4               7   1500  1.792934
# 76837  53     0     32    8              12   1300  1.830587
# 76838  53     0     57    8               4   1500  1.726344
# 76839  53     0     38    8               4    900  1.658305
#
# [76840 rows x 7 columns]

# %% [markdown]
# ## Dataset de exemplo
#
# y = gasto das famílias
# x = renda das famílias

# %%
dataset = {
    'Y': [3011, 1305, 1879, 2654, 2849, 1068, 2892, 2543, 3074, 849, 2184, 2943, 1357, 2755, 2163, 3099, 1600, 353, 1778, 740, 2129, 3302, 2412, 2683, 2515, 2395, 2292, 1000, 600, 1864, 3027, 1978, 2791, 1982, 900, 1964, 1247, 3067, 700, 1500, 3110, 2644, 1378, 2601, 501, 1292, 2125, 1431, 2260, 1770],
    'X': [9714, 3728, 6062, 8845, 8378, 3338, 8507, 7947, 9915, 1632, 6825, 8918, 4100, 9184, 6180, 9997, 4500, 1069, 5925, 2466, 6083, 9712, 7780, 8383, 7185, 7483, 7640, 2100, 2000, 6012, 8902, 5345, 8210, 5662, 2700, 6546, 2900, 9894, 1500, 5000, 8885, 8813, 3446, 7881, 1164, 3401, 6641, 3329, 6648, 4800]
}

# %%
# está como lista

dataset
# Out:
# {'X': [9714,
#   3728,
#   6062,
#   8845,
#   8378,
#   3338,
#   8507,
#   7947,
#   9915,
#   1632,
#   6825,
#   8918,
#   4100,
#   9184,
#   6180,
#   9997,
#   4500,
#   1069,
#   5925,
#   2466,
#   6083,
#   9712,
#   7780,
#   8383,
#   7185,
#   7483,
#   7640,
#   2100,
#   2000,
#   6012,
#   8902,
#   5345,
#   8210,
#   5662,
#   2700,
#   6546,
#   2900,
#   9894,
#   1500,
#   5000,
#   8885,
#   8813,
#   3446,
#   7881,
#   1164,
#   3401,
#   6641,
#   3329,
#   6648,
#   4800],
#  'Y': [3011,
#   1305,
#   1879,
#   2654,
#   2849,
#   1068,
#   2892,
#   2543,
#   3074,
#   849,
#   2184,
#   2943,
#   1357,
#   2755,
#   2163,
#   3099,
#   1600,
#   353,
#   1778,
#   740,
#   2129,
#   3302,
#   2412,
#   2683,
#   2515,
#   2395,
#   2292,
#   1000,
#   600,
#   1864,
#   3027,
#   1978,
#   2791,
#   1982,
#   900,
#   1964,
#   1247,
#   3067,
#   700,
#   1500,
#   3110,
#   2644,
#   1378,
#   2601,
#   501,
#   1292,
#   2125,
#   1431,
#   2260,
# ...

# %%
# transformando em DataFrame

dataset_df = pd.DataFrame(dataset)
dataset_df
# Out:
#        Y     X
# 0   3011  9714
# 1   1305  3728
# 2   1879  6062
# 3   2654  8845
# 4   2849  8378
# 5   1068  3338
# 6   2892  8507
# 7   2543  7947
# 8   3074  9915
# 9    849  1632
# 10  2184  6825
# 11  2943  8918
# 12  1357  4100
# 13  2755  9184
# 14  2163  6180
# 15  3099  9997
# 16  1600  4500
# 17   353  1069
# 18  1778  5925
# 19   740  2466
# 20  2129  6083
# 21  3302  9712
# 22  2412  7780
# 23  2683  8383
# 24  2515  7185
# 25  2395  7483
# 26  2292  7640
# 27  1000  2100
# 28   600  2000
# 29  1864  6012
# 30  3027  8902
# 31  1978  5345
# 32  2791  8210
# 33  1982  5662
# 34   900  2700
# 35  1964  6546
# 36  1247  2900
# 37  3067  9894
# 38   700  1500
# 39  1500  5000
# 40  3110  8885
# 41  2644  8813
# 42  1378  3446
# 43  2601  7881
# 44   501  1164
# 45  1292  3401
# 46  2125  6641
# 47  1431  3329
# 48  2260  6648
# 49  1770  4800

# %%
dataset_df.shape
# Out:
# (50, 2)

# %%
dataset_df.describe()
# Out:
#                  Y            X
# count    50.000000    50.000000
# mean   2011.120000  6065.500000
# std     817.214648  2707.187812
# min     353.000000  1069.000000
# 25%    1362.250000  3516.500000
# 50%    2127.000000  6363.000000
# 75%    2675.750000  8381.750000
# max    3302.000000  9997.000000

# %%
sns.boxplot(data=dataset_df)

# %%
# Orientação horizontal
sns.boxplot(data=dataset_df, orient='h')

# %%
# Por convenção, usar "ax"

ax = sns.lmplot(x='X', y='Y', data=dataset_df)
ax.fig.set_size_inches(8, 5)
ax.fig.suptitle('Reta de Regressão - Gasto x Renda', fontsize=18)
ax.set_xlabels('Renda das Famílias', fontsize=12)
ax.set_ylabels('Gasto das Famílias', fontsize=12)
ax

# %%
# Análise de Correlação
dataset_df.corr()
# Out:
#           Y         X
# Y  1.000000  0.984835
# X  0.984835  1.000000

# %%
import statsmodels.api as sm

# %%
Y = dataset_df.Y
X = sm.add_constant(dataset_df.X)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
Y.head(5)
# Out:
# 0    3011
# 1    1305
# 2    1879
# 3    2654
# 4    2849
# Name: Y, dtype: int64

# %%
X.head(5)
# Out:
#    const     X
# 0    1.0  9714
# 1    1.0  3728
# 2    1.0  6062
# 3    1.0  8845
# 4    1.0  8378

# %%
len(Y)
# Out:
# 50

# %%
len(X)
# Out:
# 50

# %%
# Criar uma Regressão com essas duas variáveis: Y e X
resultado_regressao = sm.OLS(Y, X).fit()

# %%
# Resultado da Regressão
resultado_regressao.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                     7767.
# Date:                Mon, 27 Jun 2022   Prob (F-statistic):           1.07e-32
# Time:                        13:34:53   Log-Likelihood:                -194.05
# No. Observations:                  27   AIC:                             392.1
# Df Residuals:                      25   BIC:                             394.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -168.3212     77.566     -2.170      0.040    -328.071      -8.571
# ...

# %%
# Outro formato de visualização
print(resultado_regressao.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                     7767.
# Date:                Mon, 27 Jun 2022   Prob (F-statistic):           1.07e-32
# Time:                        13:35:02   Log-Likelihood:                -194.05
# No. Observations:                  27   AIC:                             392.1
# Df Residuals:                      25   BIC:                             394.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -168.3212     77.566     -2.170      0.040    -328.071      -8.571
# ...

# %%
# Incluir uma variável no dataset com o Y_Predict, ou previsão

dataset_df['Y_previsto'] = resultado_regressao.predict()
dataset_df.head()
# Out:
#       Y     X   Y_previsto
# 0  3011  9714  3095.785086
# 1  1305  3728  1316.203010
# 2  1879  6062  2010.079483
# 3  2654  8845  2837.439476
# 4  2849  8378  2698.604723

# %% [markdown]
# # Aula 2

# %%
df.head(5)
# Out:
#    UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0  11     0     23    8              12    800  1.603808
# 1  11     1     23    2              12   1150  1.739790
# 2  11     1     35    8              15    880  1.760444
# 3  11     0     46    2               6   3500  1.783158
# 4  11     1     47    8               9    150  1.690631

# %%
amostra = df.query('Renda < 5000').sample(n = 20, random_state = 101)

# %%
amostra.head(5)
# Out:
#        UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 5051   14     0     39    8               6   1500  1.616243
# 72082  52     0     29    8               7   1000  1.752518
# 5521   15     1     21    8              12   3500  1.694016
# 13849  22     0     49    2              13   1570  1.804156
# 14285  22     0     29    8               9    600  1.785481

# %%
amostra.shape
# Out:
# (20, 7)

# %%
# Matriz de Covariância

amostra[['Idade', 'Renda', 'Anos de Estudo', 'Altura']].cov()
# Out:
#                       Idade          Renda  Anos de Estudo    Altura
# Idade            134.410526   -4947.968421      -16.410526  0.016506
# Renda          -4947.968421  764668.326316     2209.021053 -7.138236
# Anos de Estudo   -16.410526    2209.021053       16.936842  0.111281
# Altura             0.016506      -7.138236        0.111281  0.003354

# %%
# Cálculo da Variância

amostra.Idade.var()
# Out:
# 134.4105263157895

# %%
x = amostra.Renda
y = amostra.Idade

ax_1 = sns.scatterplot(x, y)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
ax_1 = sns.scatterplot(x, y)
ax_1.figure.set_size_inches(8, 5)
ax_1.hlines(y = y.mean(), xmin = x.min(), xmax = x.max(), colors='black', linestyles='dashed')
ax_1.vlines(x = x.mean(), ymin = y.min(), ymax = y.max(), colors='black', linestyles='dashed')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
x = amostra.Renda
y = amostra['Anos de Estudo']

ax_2 = sns.scatterplot(x, y)

ax_2.figure.set_size_inches(8, 5)
ax_2.hlines(y = y.mean(), xmin = x.min(), xmax = x.max(), colors='black', linestyles='dashed')
ax_2.vlines(x = x.mean(), ymin = y.min(), ymax = y.max(), colors='black', linestyles='dashed')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
S_xy = df[['Altura', 'Renda']].cov()
S_xy
# Out:
#           Altura         Renda
# Altura  0.006355 -1.078964e+00
# Renda  -1.078964  1.104491e+07

# %%
S_xy = S_xy.Altura.loc['Renda']
S_xy
# Out:
# -1.0789639314252715

# %%
S_x = df.Altura.std()
S_y = df.Renda.std()

# %%
r_xy = S_xy / (S_x * S_y)
r_xy
# Out:
# -0.0040726081434002874

# %%
dataset_df[['X', 'Y']].corr()
# Out:
#           X         Y
# X  1.000000  0.984835
# Y  0.984835  1.000000

# %%
df[["Altura", "Renda"]].corr()
# Out:
#           Altura     Renda
# Altura  1.000000 -0.004073
# Renda  -0.004073  1.000000

# %%
# Exercício extra!
import numpy as np

sigma_XY = 2178803.59
sigma_X_2 = 7328865.85
sigma_Y_2 = 667839.78

sigma_X = np.sqrt(sigma_X_2)
sigma_Y = np.sqrt(sigma_Y_2)

r_XY = sigma_XY / (sigma_X * sigma_Y)
print('Correlação ->', r_XY.round(4))
# Out:
# Correlação -> 0.9848

# %% [markdown]
# # Aula 3
#
# Regressão Linear
#
# MÉTODO DOS MÍNIMOS QUADRADOS (resíduos)

# %%
n = len(dataset_df)

# %%
n
# Out:
# 50

# %%
SOMA_Y = dataset_df.Y.sum()
SOMA_Y
# Out:
# 100556

# %%
SOMA_X = dataset_df.X.sum()
SOMA_X
# Out:
# 303275

# %%
dataset_df['X2'] = dataset_df.X ** 2

# %%
dataset_df.head()
# Out:
#       Y     X        X2
# 0  3011  9714  94361796
# 1  1305  3728  13897984
# 2  1879  6062  36747844
# 3  2654  8845  78234025
# 4  2849  8378  70190884

# %%
SOMA_X2 = dataset_df.X2.sum()

# %%
SOMA_X2
# Out:
# 2198628939

# %%
# Outra possibilidade de somar 

SOMA_X2 = dataset_df.X.apply(lambda x: x**2).sum()
SOMA_X2
# Out:
# 2198628939

# %%
SOMA_Y2 = SOMA_Y2 = dataset_df.Y.apply(lambda y: y**2).sum()
SOMA_Y2
# Out:
# 234954332

# %%
dataset_df['XY'] = dataset_df.X * dataset_df.Y

# %%
dataset_df.head()
# Out:
#       Y     X        X2        XY
# 0  3011  9714  94361796  29248854
# 1  1305  3728  13897984   4865040
# 2  1879  6062  36747844  11390498
# 3  2654  8845  78234025  23474630
# 4  2849  8378  70190884  23868922

# %%
SOMA_XY = dataset_df.XY.sum()

# %%
SOMA_XY
# Out:
# 716683794

# %%
SOMA_XY = dataset_df.apply(lambda data: data.X * data.Y, axis = 1).sum()
SOMA_XY
# Out:
# 716683794

# %%
dataset_df.drop(['X2', 'XY'], axis=1, inplace=True)

# %%
dataset_df.head()
# Out:
#       Y     X
# 0  3011  9714
# 1  1305  3728
# 2  1879  6062
# 3  2654  8845
# 4  2849  8378

# %%
dataset_df.shape
# Out:
# (50, 2)

# %%
numerador = n * SOMA_XY - SOMA_X * SOMA_Y
denominador = n * SOMA_X2 - (SOMA_X)**2
BETA_2 = numerador / denominador
BETA_2
# Out:
# 0.29729069099372424

# %%
BETA_1 = dataset_df.Y.mean() - BETA_2 * dataset_df.X.mean()
BETA_1
# Out:
# 207.90331377756547

# %%
import statsmodels. api as sm

# %%
Y = dataset_df
X = sm.add_constant(dataset_df.X)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
Y.head(3)
# Out:
#       Y     X
# 0  3011  9714
# 1  1305  3728
# 2  1879  6062

# %%
X.head(3)
# Out:
#    const     X
# 0    1.0  9714
# 1    1.0  3728
# 2    1.0  6062

# %%
# Estimando o Modelo
resultado_regressao = sm.OLS(Y, X, missing='drop').fit()

# %%
# Visualizando os parâmetros estimados

BETA_1
# Out:
# 207.90331377756547

# %%
BETA_2
# Out:
# 0.29729069099372424

# %%
resultado_regressao

# %%
resultado_regressao.params
# Out:
#                 0             1
# const  207.903314 -7.398526e-13
# X        0.297291  1.000000e+00

# %%
beta_1 = resultado_regressao.params[0]
beta_1
# Out:
# const    207.903314
# X          0.297291
# Name: 0, dtype: float64

# %%
beta_2 = resultado_regressao.params[1]
beta_2
# Out:
# const   -7.398526e-13
# X        1.000000e+00
# Name: 1, dtype: float64

# %%
# intervalo de confiança para os parâmetros estimados
resultado_regressao.conf_int(alpha=0.05)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-1904e91da07a> in <module>()
#       1 # intervalo de confiança para os parâmetros estimados
# ----> 2 resultado_regressao.conf_int(alpha=0.05)
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/wrapper.py in wrapper(self, *args, **kwargs)
#      93             obj = data.wrap_output(func(results, *args, **kwargs), how[0], how[1:])
#      94         elif how:
# ---> 95             obj = data.wrap_output(func(results, *args, **kwargs), how)
#      96         return obj
#      97
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in conf_int(self, alpha, cols)
#    1540         """
#    1541         # keep method for docstring for now
# -> 1542         ci = super(RegressionResults, self).conf_int(alpha=alpha, cols=cols)
#    1543         return ci
#    1544
#
# ...

# %%
dataset = {
    'Y': [670, 220, 1202, 188, 1869, 248, 477, 1294, 816, 2671, 1403, 1586, 3468, 973, 701, 5310, 10950, 2008, 9574, 28863, 6466, 4274, 6432, 1326, 1423, 3211, 2140], 
    'X': [1.59, 0.56, 2.68, 0.47, 5.2, 0.58, 1.32, 3.88, 2.11, 5.53, 2.6, 2.94, 6.62, 1.91, 1.48, 10.64, 22.39, 4.2, 21.9, 59.66, 14.22, 9.57, 14.67, 3.28, 3.49, 6.94, 6.25]
}

# %%
DF = pd.DataFrame(dataset)

# %%
DF
# Out:
#         Y      X
# 0     670   1.59
# 1     220   0.56
# 2    1202   2.68
# 3     188   0.47
# 4    1869   5.20
# 5     248   0.58
# 6     477   1.32
# 7    1294   3.88
# 8     816   2.11
# 9    2671   5.53
# 10   1403   2.60
# 11   1586   2.94
# 12   3468   6.62
# 13    973   1.91
# 14    701   1.48
# 15   5310  10.64
# 16  10950  22.39
# 17   2008   4.20
# 18   9574  21.90
# 19  28863  59.66
# 20   6466  14.22
# 21   4274   9.57
# 22   6432  14.67
# 23   1326   3.28
# 24   1423   3.49
# 25   3211   6.94
# 26   2140   6.25

# %%
DF.describe()
# Out:
#                   Y          X
# count     27.000000  27.000000
# mean    3694.925926   8.025185
# std     5756.438970  11.938745
# min      188.000000   0.470000
# 25%      894.500000   2.010000
# 50%     1586.000000   3.880000
# 75%     3871.000000   8.255000
# max    28863.000000  59.660000

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Y       27 non-null     int64
#  1   X       27 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 560.0 bytes

# %%
DF.shape
# Out:
# (27, 2)

# %%
SOMA_Y = DF.Y.sum()
SOMA_Y
# Out:
# 99763

# %%
SOMA_X = DF.X.sum()
SOMA_X
# Out:
# 216.68

# %%
DF['XY'] = DF.X * DF.Y

# %%
SOMA_XY = DF.apply(lambda data: data.X * data.Y, axis = 1).sum()
SOMA_XY
# Out:
# 2584589.03

# %%
SOMA_XY = DF.XY.sum()
SOMA_XY
# Out:
# 2584589.03

# %%
DF
# Out:
#         Y      X          XY
# 0     670   1.59     1065.30
# 1     220   0.56      123.20
# 2    1202   2.68     3221.36
# 3     188   0.47       88.36
# 4    1869   5.20     9718.80
# 5     248   0.58      143.84
# 6     477   1.32      629.64
# 7    1294   3.88     5020.72
# 8     816   2.11     1721.76
# 9    2671   5.53    14770.63
# 10   1403   2.60     3647.80
# 11   1586   2.94     4662.84
# 12   3468   6.62    22958.16
# 13    973   1.91     1858.43
# 14    701   1.48     1037.48
# 15   5310  10.64    56498.40
# 16  10950  22.39   245170.50
# 17   2008   4.20     8433.60
# 18   9574  21.90   209670.60
# 19  28863  59.66  1721966.58
# 20   6466  14.22    91946.52
# 21   4274   9.57    40902.18
# 22   6432  14.67    94357.44
# 23   1326   3.28     4349.28
# 24   1423   3.49     4966.27
# 25   3211   6.94    22284.34
# 26   2140   6.25    13375.00

# %%
DF.drop(['XY'], axis=1, inplace=True)

# %%
DF.head(3)
# Out:
#       Y     X
# 0   670  1.59
# 1   220  0.56
# 2  1202  2.68

# %%
len(DF)
# Out:
# 27

# %%
n = len(DF)

# %%
numerador = n * SOMA_XY - SOMA_X * SOMA_Y
denominador = n * SOMA_X2 - (SOMA_X)**2
beta_2 = numerador / denominador
beta_2
# Out:
# 0.0008114028973565402

# %%
beta_1 = DF.Y.mean() - beta_2 * DF.X.mean()
beta_1
# Out:
# 3694.919414267415

# %%
import statsmodels. api as sm

# %%
Y = DF
X = sm.add_constant(DF.X)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
print(X.head(3))
print(Y.head(3))
# Out:
#    const     X
# 0    1.0  1.59
# 1    1.0  0.56
# 2    1.0  2.68
#       Y     X
# 0   670  1.59
# 1   220  0.56
# 2  1202  2.68

# %%
resultado_regressao = sm.OLS(Y, X, missing='drop').fit()

# %%
resultado_regressao

# %%
resultado_regressao.params
# Out:
#                 0             1
# const -168.321156  2.576064e-15
# X      481.390397  1.000000e+00

# %%
import statsmodels.api as sm
import pandas as pd

dataset = {
    'Y': [670, 220, 1202, 188, 1869, 248, 477, 1294, 816, 2671, 1403, 1586, 3468, 973, 701, 5310, 10950, 2008, 9574, 28863, 6466, 4274, 6432, 1326, 1423, 3211, 2140], 
    'X': [1.59, 0.56, 2.68, 0.47, 5.2, 0.58, 1.32, 3.88, 2.11, 5.53, 2.6, 2.94, 6.62, 1.91, 1.48, 10.64, 22.39, 4.2, 21.9, 59.66, 14.22, 9.57, 14.67, 3.28, 3.49, 6.94, 6.25]
}
dataset = pd.DataFrame(dataset)

Y = dataset.Y
X = sm.add_constant(dataset.X)

resultado_regressao = sm.OLS(Y, X, missing='drop').fit()
resultado_regressao.params
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# const   -168.321156
# X        481.390397
# dtype: float64

# %% [markdown]
# Obtendo previsões
#
# passos...
#
# Análise dos resíduos, para isso é necessário
# 'y' valor observado e '^y' valor estimado

# %%
dataset_df.head(3)
# Out:
#       Y     X
# 0  3011  9714
# 1  1305  3728
# 2  1879  6062

# %%
dataset_df['Y_Previsto'] = BETA_1 + BETA_2 * dataset_df.X

# %%
dataset_df.head(3)
# Out:
#       Y     X   Y_Previsto
# 0  3011  9714  3095.785086
# 1  1305  3728  1316.203010
# 2  1879  6062  2010.079483

# %%
dataset_df.head(3)
# Out:
#       Y     X   Y_Previsto
# 0  3011  9714  3095.785086
# 1  1305  3728  1316.203010
# 2  1879  6062  2010.079483

# %%
resultado_regressao

# %%
resultado_regressao.predict()
# Out:
# array([[3095.78508609, 9714.        ],
#        [1316.2030098 , 3728.        ],
#        [2010.07948258, 6062.        ],
#        [2837.43947562, 8845.        ],
#        [2698.60472292, 8378.        ],
#        [1200.25964031, 3338.        ],
#        [2736.95522206, 8507.        ],
#        [2570.4724351 , 7947.        ],
#        [3155.54051498, 9915.        ],
#        [ 693.08172148, 1632.        ],
#        [2236.91227981, 6825.        ],
#        [2859.14169606, 8918.        ],
#        [1426.79514685, 4100.        ],
#        [2938.22101986, 9184.        ],
#        [2045.15978412, 6180.        ],
#        [3179.91835164, 9997.        ],
#        [1545.71142325, 4500.        ],
#        [ 525.70706245, 1069.        ],
#        [1969.35065792, 5925.        ],
#        [ 941.02215777, 2466.        ],
#        [2016.32258709, 6083.        ],
#        [3095.19050471, 9712.        ],
#        [2520.82488971, 7780.        ],
#        [2700.09117638, 8383.        ],
# ...

# %%
dataset_df.head(10)
# Out:
#       Y     X   Y_Previsto
# 0  3011  9714  3095.785086
# 1  1305  3728  1316.203010
# 2  1879  6062  2010.079483
# 3  2654  8845  2837.439476
# 4  2849  8378  2698.604723
# 5  1068  3338  1200.259640
# 6  2892  8507  2736.955222
# 7  2543  7947  2570.472435
# 8  3074  9915  3155.540515
# 9   849  1632   693.081721

# %%
# X = Renda da Família. Estimando o 'Gasto das Famílias' fora da amostra

def prever(x):
  return BETA_1 + BETA_2 * x

# %%
''' Portanto, na média, o gasto estimado
    para uma família com renda de 7510
    será de 2440'''

prever(7510)
# Out:
# 2440.5564031404347

# %%
resultado_regressao.predict(1, 7510)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-157-fd11c57e536d> in <module>()
# ----> 1 resultado_regressao.predict(1, 7510)
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py in predict(self, exog, transform, *args, **kwargs)
#    1036
#    1037         predict_results = self.model.predict(self.params, exog, *args,
# -> 1038                                              **kwargs)
#    1039
#    1040         if exog_index is not None and not hasattr(predict_results,
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in predict(self, params, exog)
#     362             exog = self.exog
#     363
# --> 364         return np.dot(exog, params)
#     365
#     366     def get_distribution(self, params, scale, exog=None, dist_class=None):
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ...

# %%
resultado_regressao.predict(1, 7510)[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-158-1abe46b39c1c> in <module>()
# ----> 1 resultado_regressao.predict(1, 7510)[0]
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py in predict(self, exog, transform, *args, **kwargs)
#    1036
#    1037         predict_results = self.model.predict(self.params, exog, *args,
# -> 1038                                              **kwargs)
#    1039
#    1040         if exog_index is not None and not hasattr(predict_results,
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in predict(self, params, exog)
#     362             exog = self.exog
#     363
# --> 364         return np.dot(exog, params)
#     365
#     366     def get_distribution(self, params, scale, exog=None, dist_class=None):
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ...

# %%
# Problema extra

dataset_comp = {
    'Y': [670, 220, 1202, 188, 1869, 248, 477, 1294, 816, 2671, 1403, 1586, 3468, 973, 701, 5310, 10950, 2008, 9574, 28863, 6466, 4274, 6432, 1326, 1423, 3211, 2140], 
    'X': [1.59, 0.56, 2.68, 0.47, 5.2, 0.58, 1.32, 3.88, 2.11, 5.53, 2.6, 2.94, 6.62, 1.91, 1.48, 10.64, 22.39, 4.2, 21.9, 59.66, 14.22, 9.57, 14.67, 3.28, 3.49, 6.94, 6.25]
}

# %%
ds_comp = pd.DataFrame(dataset_comp)

# %%
ds_comp.head(5)
# Out:
#       Y     X
# 0   670  1.59
# 1   220  0.56
# 2  1202  2.68
# 3   188  0.47
# 4  1869  5.20

# %%
ds_comp.corr()
# Out:
#           Y         X
# Y  1.000000  0.998395
# X  0.998395  1.000000

# %%
# Por convenção, usar "ax"

ax = sns.lmplot(x='X', y='Y', data=ds_comp)
ax.fig.set_size_inches(8, 5)
ax.fig.suptitle('Reta de Regressão - Renda x Computador', fontsize=18)
ax.set_xlabels('Renda', fontsize=12)
ax.set_ylabels('Computador', fontsize=12)
ax

# %%
sns.boxplot(data=ds_comp, orient='h')

# %%
resultado_regressao.predict([1, 2.345678])[0]
# Out:
# array([208.60066201,   2.345678  ])

# %% [markdown]
# # Aula 4
#
# Métricas e testes
# ###primeiramente obter os resíduos

# %%
dataset_df.head(5)
# Out:
#       Y     X   Y_Previsto
# 0  3011  9714  3095.785086
# 1  1305  3728  1316.203010
# 2  1879  6062  2010.079483
# 3  2654  8845  2837.439476
# 4  2849  8378  2698.604723

# %%
# Sendo 'u' = Resíduos
dataset_df['u'] = dataset_df.Y - dataset_df.Y_Previsto
dataset_df.head(3)
# Out:
#       Y     X   Y_Previsto           u
# 0  3011  9714  3095.785086  -84.785086
# 1  1305  3728  1316.203010  -11.203010
# 2  1879  6062  2010.079483 -131.079483

# %%
# Outra forma de obter os 'Resíduos' 

dataset_df['Residuos'] = resultado_regressao.resid
dataset_df.head(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-172-009bbccf2dbb> in <module>()
#       1 # Outra forma de obter os 'Resíduos'
#       2
# ----> 3 dataset_df['Residuos'] = resultado_regressao.resid
#       4 dataset_df.head(3)
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/wrapper.py in __getattribute__(self, attr)
#      39             obj = data.wrap_output(obj, how[0], *how[1:])
#      40         elif how:
# ---> 41             obj = data.wrap_output(obj, how=how)
#      42
#      43         return obj
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/data.py in wrap_output(self, obj, how, names)
#     411             return self.attach_columns(obj)
#     412         elif how == 'rows':
# --> 413             return self.attach_rows(obj)
#     414         elif how == 'cov':
#     415             return self.attach_cov(obj)
#
# ...

# %%
dataset_df.head(3)
# Out:
#       Y     X   Y_Previsto           u
# 0  3011  9714  3095.785086  -84.785086
# 1  1305  3728  1316.203010  -11.203010
# 2  1879  6062  2010.079483 -131.079483

# %%
# Caso 'Residuos' fosse criado e precisasse remover

dataset_df.drop(['Residuos', axis = 1, inplace = True])
# Out:
#   File "<ipython-input-174-79d76741b06b>", line 3
#     dataset_df.drop(['Residuos', axis = 1, inplace = True])
#                                       ^
# SyntaxError: invalid syntax

# %%
dataset_df.head(3)
# Out:
#       Y     X   Y_Previsto           u
# 0  3011  9714  3095.785086  -84.785086
# 1  1305  3728  1316.203010  -11.203010
# 2  1879  6062  2010.079483 -131.079483

# %%
dataset_df.u.mean()
# Out:
# 1.3187673175707459e-13

# %%
len(dataset_df.u)
# Out:
# 50

# %%
sns.scatterplot(x=dataset_df.X, y=dataset_df.u)

# %%
ax = sns.scatterplot(x=dataset_df.X, y=dataset_df.u)
ax.figure.set_size_inches(8,5)
ax.set_title('Resíduos (u) vs Variável Independente')
ax.set_xlabel('X')
ax.set_ylabel('Resíduos (u)')
ax

# %%
# Obs.: Por ser uma Regressão Simples, o gráfico será identico. 
        # Sendo Regressão Múltipla, o gráfico seria diferente bom como o input dos dados

ax = sns.scatterplot(x=dataset_df.Y_Previsto, y=dataset_df.u)
ax.figure.set_size_inches(8,5)
ax.set_title('Resíduos (u) vs Y_Previsto')
ax.set_xlabel('Y_Previsto')
ax.set_ylabel('Resíduos (u)')
ax

# %%
ax = sns.scatterplot(x=dataset_df.Y_Previsto, y=dataset_df.u**2)
ax.figure.set_size_inches(8,5)
ax.set_title('Resíduos² (u²) vs Y_Previsto')
ax.set_xlabel('Y_Previsto')
ax.set_ylabel('Resíduos² (u²)')
ax

# %%
SQE = dataset_df.u.apply(lambda i: i**2).sum()

# %%
SQE
# Out:
# 984986.0375191914

# %%
# Soma dos quadrados dos erros

resultado_regressao.ssr
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-188-45aaa9c0a278> in <module>()
#       1 # Soma dos quadrados dos erros
#       2
# ----> 3 resultado_regressao.ssr
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/wrapper.py in __getattribute__(self, attr)
#      33             pass
#      34
# ---> 35         obj = getattr(results, attr)
#      36         data = results.model.data
#      37         how = self._wrap_attrs.get(attr)
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/decorators.py in __get__(self, obj, type)
#      91         _cachedval = _cache.get(name, None)
#      92         if _cachedval is None:
# ---> 93             _cachedval = self.fget(obj)
#      94             _cache[name] = _cachedval
#      95
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in ssr(self)
# ...

# %%
resultado_regressao

# %%
# Soma dos quadrados totais (SQT)

SQT = dataset_df.Y.apply(lambda y: (y - dataset_df.Y.mean())**2).sum()
SQT
# Out:
# 32724149.279999997

# %%
# Soma dos quadrados da regressão (SQR)

SQR = dataset_df.Y_Previsto.apply(lambda y: (y - dataset_df.Y.mean())**2).sum()
SQR
# Out:
# 31739163.242480807

# %%
# Outra forma de determinar o SQR = 

resultado_regressao.ess
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-193-7e03747f54c0> in <module>()
#       1 # Outra forma de determinar o SQR =
#       2
# ----> 3 resultado_regressao.ess
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/wrapper.py in __getattribute__(self, attr)
#      33             pass
#      34
# ---> 35         obj = getattr(results, attr)
#      36         data = results.model.data
#      37         how = self._wrap_attrs.get(attr)
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/decorators.py in __get__(self, obj, type)
#      91         _cachedval = _cache.get(name, None)
#      92         if _cachedval is None:
# ---> 93             _cachedval = self.fget(obj)
#      94             _cache[name] = _cachedval
#      95
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in ess(self)
#    1621
# ...

# %%
# Calcular R²

R2 = SQR / SQT
R2
# Out:
# 0.9699003317369297

# %%
# Outra forma de calcular R²

resultado_regressao.rsquared
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-195-8e827eb818b5> in <module>()
#       1 # Outra forma de calcular R²
#       2
# ----> 3 resultado_regressao.rsquared
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/wrapper.py in __getattribute__(self, attr)
#      33             pass
#      34
# ---> 35         obj = getattr(results, attr)
#      36         data = results.model.data
#      37         how = self._wrap_attrs.get(attr)
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/decorators.py in __get__(self, obj, type)
#      91         _cachedval = _cache.get(name, None)
#      92         if _cachedval is None:
# ---> 93             _cachedval = self.fget(obj)
#      94             _cache[name] = _cachedval
#      95
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in rsquared(self)
# ...

# %%
# Outro exercício (Renda e Computadores)

import statsmodels.api as sm
import pandas as pd

dataset = {
    'Y': [670, 220, 1202, 188, 1869, 248, 477, 1294, 816, 2671, 1403, 1586, 3468, 973, 701, 5310, 10950, 2008, 9574, 28863, 6466, 4274, 6432, 1326, 1423, 3211, 2140], 
    'X': [1.59, 0.56, 2.68, 0.47, 5.2, 0.58, 1.32, 3.88, 2.11, 5.53, 2.6, 2.94, 6.62, 1.91, 1.48, 10.64, 22.39, 4.2, 21.9, 59.66, 14.22, 9.57, 14.67, 3.28, 3.49, 6.94, 6.25]
}
dataset = pd.DataFrame(dataset)

Y = dataset.Y
X = sm.add_constant(dataset.X)

resultado_regressao = sm.OLS(Y, X, missing='drop').fit()
resultado_regressao.rsquared
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# 0.9967917066613234

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Onde temos o número de domicílios que possuem computador (Y) e a renda total recebida por pessoas de 10 anos ou mais (X), em cada um dos estados brasileiros.
#
# Acredita-se que a posse de computadores tenha uma relação linear com a renda das famílias e para comprovar isso, podemos estimar uma regressão linear com os dados acima e avaliar os resultados obtidos.
#
# Neste problema, precisamos, inicialmente, obter as estimativas dos parâmetros de regressão.
#
# Informações extras:
#
# O valor da renda está dividido por 1.000.000, isto é, se um estado tem uma renda total de R$ 4,2, significa que ele tem uma renda total de R$ 4.200.000.
#
# Utilize o ferramental do statsmodels para obter os parâmetros.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Próximo passo,
#
# teste bicaudal

# %%
# numerador: raiz quadrada do erro quadrado médio

s = np.sqrt(resultado_regressao_resid)
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-198-c42bf76779a6> in <module>()
#       1 # numerador: raiz quadrada do erro quadrado médio
#       2
# ----> 3 s = np.sqrt(resultado_regressao_resid)
#       4 s
#
# NameError: name 'resultado_regressao_resid' is not defined

# %%
resultado_regressao.predict()
# Out:
# array([  597.08957523,   101.25746638,  1121.8051079 ,    57.93233066,
#         2334.90890819,   110.88527432,   467.11416806,  1699.47358423,
#          847.41258164,  2493.76773919,  1083.29387614,  1246.96661111,
#         3018.48327185,   751.13450225,   544.13663157,  4953.67266756,
#        10610.00983163,  1853.51851125, 10374.12853713, 28551.42992566,
#         6677.05028861,  4438.58494283,  6893.67596724,  1410.63934607,
#         1511.73132942,  3172.52819887,  2840.36882498])

# %%
resultado_regressao.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                     7767.
# Date:                Mon, 27 Jun 2022   Prob (F-statistic):           1.07e-32
# Time:                        15:12:07   Log-Likelihood:                -194.05
# No. Observations:                  27   AIC:                             392.1
# Df Residuals:                      25   BIC:                             394.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -168.3212     77.566     -2.170      0.040    -328.071      -8.571
# ...

# %%
print(resultado_regressao.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                     7767.
# Date:                Mon, 27 Jun 2022   Prob (F-statistic):           1.07e-32
# Time:                        15:12:10   Log-Likelihood:                -194.05
# No. Observations:                  27   AIC:                             392.1
# Df Residuals:                      25   BIC:                             394.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -168.3212     77.566     -2.170      0.040    -328.071      -8.571
# ...

# %%
resultado_regressao.mse_model
# Out:
# 858787220.4593601

# %%
resultado_regressao.mse_resid
# Out:
# 110564.3756996659

# %%
s = np.sqrt(resultado_regressao.mse_model)
s
# Out:
# 29305.07158256673

# %%
s = np.sqrt(resultado_regressao.mse_resid)

# %%
s2 = np.sqrt(s)
s2
# Out:
# 18.234917572413906

# %%
s
# Out:
# 332.5122188727294

# %%
s1 = s/2 -23

# %%
s1
# Out:
# 143.2561094363647

# %%
SOMA_DESVIO2 = dataset_df.X.apply(lambda x: (x - dataset_df.X.mean())**2).sum()
SOMA_DESVIO2
# Out:
# 359114426.5

# %%
s_beta_2 = s1 / np.sqrt(SOMA_DESVIO2)
s_beta_2
# Out:
# 0.007559563619372316

# %%
from scipy.stats import t as t_student

# %%
confianca = 0.95 
significancia = 1 - confianca

# %%
graus_de_liberdade = resultado_regressao.df_resid
graus_de_liberdade
# Out:
# 25.0

# %%
48-25
# Out:
# 23

# %%
graus_liberdade = 48
graus_liberdade
# Out:
# 48

# %%
probabilidade = (0.5 + (confianca / 2))
probabilidade
# Out:
# 0.975

# %%
t_alpha_2 = t_student.ppf(probabilidade, graus_liberdade)
t_alpha_2
# Out:
# 2.0106347546964454

# %%
t = (BETA_2 - 0) / s_beta_2
t
# Out:
# 39.326435487873944

# %%
resultado_regressao.tvalues[1]
# Out:
# 88.13231490233862

# %%
t >= t_alpha_2
# Out:
# True

# %%
p_valor = 2 * (t_student.sf(t, graus_liberdade))
p_valor
# Out:
# 3.5626951643366236e-38

# %%
# outra forma de obter p_valor

''' Necessário refazer essa Aula 4
    Acredito que o erro está no "resultado_regressao"'''

p_valor = resultado_regressao.pvalues[1]
p_valor
# Out:
# 1.0658600206888955e-32

# %%
print(resultado_regressao.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                     7767.
# Date:                Mon, 27 Jun 2022   Prob (F-statistic):           1.07e-32
# Time:                        15:31:30   Log-Likelihood:                -194.05
# No. Observations:                  27   AIC:                             392.1
# Df Residuals:                      25   BIC:                             394.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -168.3212     77.566     -2.170      0.040    -328.071      -8.571
# ...

# %%
# O resultado da regressão acima é ref. a outro exercício!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Aula 4
#
# Refazer!!! Erro na Regressão. Dados divergentes. Amostra, etc

# %% [markdown]
# # Aula 4: Extra

# %% [markdown]
# # Aula 5
